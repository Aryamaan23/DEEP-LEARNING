# %%
import pandas as pd
import numpy as np
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Bitcoin_2017 = pd.read_csv('/content/drive/My Drive/Technocolabs/Bitcoin/bitcoin_cash_price.csv')
Bitcoin_2017.head()
# Out:
#            Date     Open     High  ...    Close       Volume      Market Cap
# 0  Feb 20, 2018  1543.27  1569.03  ...  1418.73  820,947,000  26,199,800,000
# 1  Feb 19, 2018  1483.34  1553.81  ...  1534.77  578,906,000  25,179,700,000
# 2  Feb 18, 2018  1552.10  1641.40  ...  1487.46  907,873,000  26,344,200,000
# 3  Feb 17, 2018  1548.48  1568.64  ...  1551.39  641,719,000  26,280,100,000
# 4  Feb 16, 2018  1373.16  1558.66  ...  1552.20  961,010,000  23,302,000,000
#
# [5 rows x 7 columns]

# %%
Bitcoin_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        213 non-null    object
#  1   Open        213 non-null    float64
#  2   High        213 non-null    float64
#  3   Low         213 non-null    float64
#  4   Close       213 non-null    float64
#  5   Volume      213 non-null    object
#  6   Market Cap  213 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 11.8+ KB

# %%
Bitcoin_2017['Date'] = pd.to_datetime(Bitcoin_2017['Date'])

# %%
Bitcoin_2017.head()
# Out:
#         Date     Open     High      Low    Close       Volume      Market Cap
# 0 2018-02-20  1543.27  1569.03  1414.35  1418.73  820,947,000  26,199,800,000
# 1 2018-02-19  1483.34  1553.81  1483.34  1534.77  578,906,000  25,179,700,000
# 2 2018-02-18  1552.10  1641.40  1428.49  1487.46  907,873,000  26,344,200,000
# 3 2018-02-17  1548.48  1568.64  1517.14  1551.39  641,719,000  26,280,100,000
# 4 2018-02-16  1373.16  1558.66  1369.68  1552.20  961,010,000  23,302,000,000

# %%
# creating a column `iso_week` by stripping the Year and Week from `date`
Bitcoin_2017['iso_week'] = Bitcoin_2017['Date'].apply(
    lambda x: x.strftime('%Y-%U'))

# %%
Bitcoin_2017['week'] = Bitcoin_2017['Date'].apply(
    lambda x: x.strftime('%U'))

# %%
Bitcoin_2017.head()
# Out:
#         Date     Open     High  ...      Market Cap  iso_week week
# 0 2018-02-20  1543.27  1569.03  ...  26,199,800,000   2018-07   07
# 1 2018-02-19  1483.34  1553.81  ...  25,179,700,000   2018-07   07
# 2 2018-02-18  1552.10  1641.40  ...  26,344,200,000   2018-07   07
# 3 2018-02-17  1548.48  1568.64  ...  26,280,100,000   2018-06   06
# 4 2018-02-16  1373.16  1558.66  ...  23,302,000,000   2018-06   06
#
# [5 rows x 9 columns]

# %%
# changing the dtypes
Bitcoin_2017['week']=Bitcoin_2017['week'].astype(int)
Bitcoin_2017['Date']=Bitcoin_2017['Date'].astype(str)

# %%
# Removing the ',' from Volume and Market Cap
Bitcoin_2017['Volume'] = Bitcoin_2017['Volume'].apply(lambda x: x.replace(',', ''))
Bitcoin_2017['Market Cap'] = Bitcoin_2017['Market Cap'].apply(lambda x: x.replace(',', ''))

# %%
Bitcoin_2017['Volume'] = Bitcoin_2017['Volume'].astype(int)

# %%
Bitcoin_2017.head()
# Out:
#          Date     Open     High      Low  ...     Volume   Market Cap iso_week week
# 0  2018-02-20  1543.27  1569.03  1414.35  ...  820947000  26199800000  2018-07    7
# 1  2018-02-19  1483.34  1553.81  1483.34  ...  578906000  25179700000  2018-07    7
# 2  2018-02-18  1552.10  1641.40  1428.49  ...  907873000  26344200000  2018-07    7
# 3  2018-02-17  1548.48  1568.64  1517.14  ...  641719000  26280100000  2018-06    6
# 4  2018-02-16  1373.16  1558.66  1369.68  ...  961010000  23302000000  2018-06    6
#
# [5 rows x 9 columns]

# %%
Bitcoin_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        213 non-null    object
#  1   Open        213 non-null    float64
#  2   High        213 non-null    float64
#  3   Low         213 non-null    float64
#  4   Close       213 non-null    float64
#  5   Volume      213 non-null    int64
#  6   Market Cap  213 non-null    object
#  7   iso_week    213 non-null    object
#  8   week        213 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 15.1+ KB

# %%
"""
Series of normalization functions useful
for normalizing time-series data.
"""

def z_score(series):
    """
    Computes the normalized value using the Z-score
    technique. The Z-score is a technique used for
    normalizing Gaussian distributions representing
    each observation in relation to the distribution's
    mean and standard deviation. For precise definitions,
    see the Wikipedia article:
    
        https://en.wikipedia.org/wiki/Standard_score
    
    Parameters
    ----------
    serie: list
        List with sequential values to use.
    
    Returns
    -------
    result: list
        List with the normalized results.
    """
    result = (series - series.mean()) / series.std(ddof=0)
    return result

def point_relative_normalization(series, reverse=False, last_value=None):
    """
    Computes the normalized value for the values of a
    given series by using the first element of the serie as p_0
    as a reference for each p_i.
    
    This technique comes from Siraj Raval's YouTube video
    "How to Predict Stock Prices Easily - Intro to Deep Learning #7",
    available at:
    
        https://www.youtube.com/watch?v=ftMq5ps503w
    
    Parameters
    ----------
    serie: list
        List with sequential values to use.
    
    reverse: bool, default True
        If the method should de-normalize data.
    
    last_value: int or float
        Used to de-normalize a dataset. Needs to 
        be passed if `reverse` is True.
    
    Returns
    -------
    result: list
        List with the normalized results.
    """
    if reverse:
        result = last_value * (series + 1)
    else:
        result = (series / series[0]) - 1

    return result

def maximum_and_minimum_normalization(series, boundary=(0, 1)):
    """
    Computes the normalized value for the values of a
    given serie by using that series maximum and minimum
    values.
    
    This technique is a direct implementation from 
    scikit-learn, available at:
    
        http://scikit-learn.org/stable/modules/generated/\
            sklearn.preprocessing.MinMaxScaler.html
    
    Parameters
    ----------
    serie: list
        List with sequential values to use.
    
    boundary: set
        Maximum and minimum values used to
        scale the series.
        
    Returns
    -------
    result: list
        List with the normalized results.
    """
    range_min, range_max = boundary
    standard_deviation = (series - series.min(axis=0)) / (series.max(axis=0) - series.min(axis=0))
    result = standard_deviation * (range_max - range_min) + range_min
    return result

# %%
"""
Helper class and methods for making manipulating
data for models.
"""
import numpy as np

#from cryptonic.models import normalizations


class ModelHelper:
    """
    Class with utility functions that aid in 
    the process of training LSTM models with Keras.

    """
    def __init__(self):
        pass

    def create_groups(self, data, start=0, group_size=7, normalize=True):
        """
        Creates distinct groups from a given continuous series.

        Parameters
        ----------
        data: np.array
            Series of continious observations.
        
        start: int
            Starting point for the series. This 
            is used to prune earlier observations
            from the series in case the series is
            too long or too short.

        group_size: int, default 7
            Determines how large the groups are. That is,
            how many observations each group contains.
        
        normalize: bool
            If the method should normalize data or not.
            Normalization is done using 

                point_relative_normalization()

        Returns
        -------
        A Numpy array object. 
        """
        samples = list()
        for i in range(0, len(data), group_size):
            sample = list(data[start + i:i + group_size])
            if len(sample) == group_size:
                if normalize:
                    sample = point_relative_normalization(sample)

                samples.append(np.array(sample).reshape(1, group_size).tolist())

        A = np.array(samples)
        return A.reshape(1, A.shape[0], group_size)

    def split_lstm_input(self, groups):
        """
        Splits groups in a format expected by 
        the LSTM layer. 
        
        Parameters
        ----------
        groups: np.array
            Numpy array with the organized sequences.
        
        Returns
        -------
        X, Y: np.array
            Numpy arrays with the shapes required by
            the LSTM layer. X with (1, a - 1, b)
            and Y with (1, b). Where a is the total
            number of groups in `group` and b the
            number of observations per group.
        """
        X = groups[0:,:-1].reshape(1, groups.shape[1] - 1, groups.shape[2])
        Y = groups[0:,-1:][0]

        return X, Y

    def normalize(self):
        """
        Normalizes a series using point-relative normalization.

        Parameters
        ----------

        Returns
        -------
        """
        point_relative_normalization()

    def denormalize(self, series, last_value):
        """
        De-normalizes a series using the latest
        value available from data.
        
        Parameters
        ----------
        series: numpy array
            Series with normalized values.
        
        last_value: float
            Numerical value that represents the
            last value from the dataset.
        
        Returns
        -------
        """
        result = last_value * (series + 1)
        return result

    def mape(self, A, B):
        """
        Calcualtes the mean absolute persentage error
        from two series. Original solution from:
        
            https://stats.stackexchange.com/questions/58391/\
                mean-absolute-percentage-error-mape-in-scikit-learn
        """
        return np.mean(np.abs((A - B) / (1 - A))) * 100

    def rmse(self, A, B):
        """
        Calculates the root mean square error from
        two series. Original solution from:

            https://stackoverflow.com/questions/16774849\
                /mean-squared-error-in-numpy
        """
        return np.sqrt(np.square(np.subtract(A, B)).mean())
    
    def mse(self, A, B):
        """
        Calculates the mean square error from
        two series. Original solution from:

            https://stackoverflow.com/questions/16774849\
                /mean-squared-error-in-numpy
        """
        return np.square(np.subtract(A, B)).mean()

# %%
"""
Creates a deep learning model abstraction.
"""
from datetime import datetime, timedelta

from keras.models import load_model
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers.core import Dense, Activation

#from cryptonic.models.helper import ModelHelper
#from cryptonic.models.normalizations import point_relative_normalization


class Model(ModelHelper):
    """
    Class that encapsulates an LSTM model
    that we have been building. This class makes it
    easy to work with the different functions
    used to work with the model.
    
    Parameters
    ----------
    path: str
        Location to load model from.

    data: pandas DataFrame
        Pandas dataframe with the variable from
        `variable` privided. This is used
        to eventually train and run the model.
    
    variable: str
        Variable to use from `data`.
    
    predicted_period_size: int
        Number of predicted time periods predictions
        to make.
    
    holdout: int, default 0
        Number of periods to hold-out from the 
        training set.

    """
    def __init__(self, data, variable, predicted_period_size, path=None, 
                 holdout=0, normalize=True):

        self.path = path
        self.data = data
        self.variable = variable
        self.predicted_period_size = predicted_period_size
        self.holdout = holdout

        if path:
            self.model = load_model(self.path)

        self.X, self.Y = self.__prepare_data(normalize=normalize)
        self.__extract_last_series_value()

        super().__init__()

    def __extract_last_series_value(self):
        """
        Method for extracting the last value from
        a series prior to normalization. This value
        is then used for denormalizing the set.
        """
        if self.remainder:
            self.last_value = self.data.sort_values('date', ascending=False)\
                                [:-self.remainder][self.variable].values[0]
            
            self.last_date = self.data.sort_values('date', ascending=False)\
                                [:-self.remainder]['date'].values[0]
        else:
            self.last_value = self.data.sort_values('date', ascending=False)\
                                [self.variable].values[0]
            
            self.last_date = self.data.sort_values('date', ascending=False)\
                                ['date'].values[0]
    
    def __prepare_data(self, normalize):
        """
        Prepares data for model.

        Parameters
        ----------
        normalize: bool
            If the method should normalize data or not.
            Normalization is done using 

                point_relative_normalization()

        Returns
        -------
        X and Y prepared for training.
        """
        series = self.data[self.variable].values
        self.remainder = len(series) % self.predicted_period_size

        groups = self.create_groups(data=series, 
                                    group_size=self.predicted_period_size,
                                    normalize=normalize)
        
        if self.holdout == 0:
            self.holdout_groups = []
        else:
            self.holdout_groups = groups[::-self.holdout]
            groups = groups[::-self.holdout]

        self.default_number_of_periods = groups.shape[1] - 1

        return self.split_lstm_input(groups)

    def build(self, number_of_periods=None, period_length=7, batch_size=1):
        """
        Builds an LSTM model using Keras. This function
        works as a simple wrapper for a manually created
        model.
        
        Parameters
        ----------
        period_length: int
            The size of each observation used as input.
        
        number_of_periods: int, default None
            The number of periods available in the 
            dataset. If None, the model will be built
            using all available periods - 1 (used for validation).
        
        batch_size: int
            The size of the batch used in each training
            period.
        
        Returns
        -------
        model: Keras model
            Compiled Keras model that can be trained
            and stored in disk.
        """
        if not number_of_periods:
            number_of_periods = self.default_number_of_periods

        self.model = Sequential()
        self.model.add(LSTM(
            units=period_length,
            batch_input_shape=(batch_size, number_of_periods, period_length),
            input_shape=(number_of_periods, period_length),
            return_sequences=False, stateful=False))

        self.model.add(Dense(units=period_length))
        self.model.add(Activation("linear"))

        self.model.compile(loss="mse", optimizer="rmsprop")

        return self.model

    def save(self, path):
        """
        Stores trained model in disk. Useful
        for storing trained models.
        
        Parameters
        ----------
        path: str
            Location of where to store model.
        """
        return self.model.save(path)
    
    def predict(self, denormalized=False, return_dict=False):
        """
        Makes a prediction based on input data.

        Parameters
        ----------
        denormalized: bool, default True
            If method should denormalize data. Method
            will use the point_relative_normalization()
        
        return_dict: bool, default False
            If should return dict that can be serializable
            as JSON. Useful for returning prediction
            results with dates as keys.

        """
        predictions = self.model.predict(x=self.X)
        if denormalized:
            predictions = point_relative_normalization(series=predictions, 
                                                       reverse=True, 
                                                       last_value=self.last_value)
        
        dates = []
        base_date = datetime.strptime(self.last_date, "%Y-%m-%d")
        for i in range(1, len(predictions[0] + 1)):
            d = (base_date + timedelta(days=i)).strftime("%Y-%m-%d")
            dates.append(d)

        results = []
        for d,p in zip(dates, predictions[0].tolist()):
            results.append({
                'date': d,
                'prediction': round(p, 2)
            })
        
        if return_dict:
            return results
        
        else:
            return predictions[0]

    def train(self, data=None, epochs=300, verbose=0):
        """
        Trains model using data from class. 

        Parameters
        ----------
        X: pandas DataFrame
            Pandas dataframe with `variable` used to
            fir model for the fist time.

        epochs: int
            Number of epochs to train model for.
        
        verbose: int, default 0
            Verbosity level to use. The default (0)
            means that nothing is printed on the
            screen.
        
        Returns
        -------
        Metrics from the model history.
        """
        if data is not None:
            self.data = data
            self.X, self.Y = self.__prepare_data(normalize=self.normalize)
            self.__extract_last_series_value()

        self.train_history = self.model.fit(
            x=self.X, y=self.Y,
            batch_size=1, epochs=epochs,
            verbose=verbose, shuffle=False)
        #now = datetime.now()
        #self.last_trained = now.strftime('%Y-%m-%d %H:%M:%S')
        return self.train_history

    def evaluate(self, metrics=['mse', 'rmse', 'mape']):
        """
        Evaluates model using provided metrics. The evaluation
        """
        y = point_relative_normalization(series=self.Y[0], 
                                         reverse=True, 
                                         last_value=self.last_value)

        results = {}
        for metric in metrics:
            if metric == 'mse':
                r = round(
                        self.mse(A=self.Y[0], B=self.predict()), 2)

            else:
                r = round(
                        getattr(self, metric)(
                        A=self.predict(denormalized=True)[0], 
                        B=y), 2)

            results[metric] = r

        return results

# %%
import pandas as pd
import numpy as np

import time
import pytz
import json

import math  

import datetime
from datetime import datetime, timedelta

from threading import Thread

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.dates as mdates



from sklearn import preprocessing, model_selection, neighbors, svm
from sklearn.preprocessing import StandardScaler, RobustScaler, MaxAbsScaler
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error

from tqdm import tqdm as tqdm

# %%
Bitcoin_2017.head()
# Out:
#          Date     Open     High      Low  ...     Volume   Market Cap iso_week week
# 0  2018-02-20  1543.27  1569.03  1414.35  ...  820947000  26199800000  2018-07    7
# 1  2018-02-19  1483.34  1553.81  1483.34  ...  578906000  25179700000  2018-07    7
# 2  2018-02-18  1552.10  1641.40  1428.49  ...  907873000  26344200000  2018-07    7
# 3  2018-02-17  1548.48  1568.64  1517.14  ...  641719000  26280100000  2018-06    6
# 4  2018-02-16  1373.16  1558.66  1369.68  ...  961010000  23302000000  2018-06    6
#
# [5 rows x 9 columns]

# %%
Bitcoin_2017.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# iso_week      0
# week          0
# dtype: int64

# %%
#  Time-series plot for `close` variable
Bitcoin_2017.set_index('Date')['Close'].plot(
    linewidth=2,
    figsize=(14, 4),
    color='#79A8A5');

# %%
#  Time-series plot for `Volume` variable
Bitcoin_2017.set_index('Date')['Volume'].plot(
    linewidth=2,
    figsize=(14, 4),
    color='#79A8A5');

# %%
#
#  Using the Pandas API, filter the dataframe
#  for observations from 2017 only. 
# 
#  Hint: use the `date` variable.
#

Bitcoin_2017 = Bitcoin_2017[Bitcoin_2017['Date'] >= '2017-01-01']

# %%
#  Keep only the `close` and `volume` variables
model_data = Bitcoin_2017[['Date', 'iso_week', 'Close', 'Volume']]
model_data.columns = ['date', 'iso_week', 'close', 'volume']
model_data.head()
# Out:
#          date iso_week    close     volume
# 0  2018-02-20  2018-07  1418.73  820947000
# 1  2018-02-19  2018-07  1534.77  578906000
# 2  2018-02-18  2018-07  1487.46  907873000
# 3  2018-02-17  2018-06  1551.39  641719000
# 4  2018-02-16  2018-06  1552.20  961010000

# %%
model_data.head()
# Out:
#          date iso_week    close     volume
# 0  2018-02-20  2018-07  1418.73  820947000
# 1  2018-02-19  2018-07  1534.77  578906000
# 2  2018-02-18  2018-07  1487.46  907873000
# 3  2018-02-17  2018-06  1551.39  641719000
# 4  2018-02-16  2018-06  1552.20  961010000

# %%
M = Model(data=model_data,
          variable='close',
          predicted_period_size=7)

# %%
M.build()

# %%
M.train(epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0119
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0103
# Epoch 3/100
# 1/1 [==============================] - 0s 982us/step - loss: 0.0092
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0070
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0064
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0059
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0050
# Epoch 11/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0046
# Epoch 12/100
# 1/1 [==============================] - 0s 917us/step - loss: 0.0042
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 14/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0035
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0032
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 17/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 20/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0019
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9079e-04
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 7.7279e-04
# Epoch 28/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6745e-04
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.7394e-04
# Epoch 30/100
# 1/1 [==============================] - 0s 983us/step - loss: 4.9137e-04
# Epoch 31/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1884e-04
# Epoch 32/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5547e-04
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0038e-04
# Epoch 34/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5271e-04
# Epoch 35/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1165e-04
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7643e-04
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4636e-04
# Epoch 38/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2078e-04
# Epoch 39/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.9118e-05
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.0846e-05
# Epoch 41/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.5506e-05
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2692e-05
# Epoch 43/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2047e-05
# Epoch 44/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3258e-05
# Epoch 45/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6054e-05
# Epoch 46/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0194e-05
# Epoch 47/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5471e-05
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1702e-05
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.7288e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.4122e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6330e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2876e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2878e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5589e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0384e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7501e-07
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2746e-07
# Epoch 58/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6320e-07
# Epoch 59/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5728e-07
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1005e-08
# Epoch 61/100
# 1/1 [==============================] - 0s 3ms/step - loss: 5.0910e-08
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7637e-08
# Epoch 63/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6022e-08
# Epoch 64/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4063e-08
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7277e-07
# Epoch 66/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2114e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9500e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 3ms/step - loss: 7.1108e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.0577e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.3630e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7356e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4510e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.1273e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3851e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0047e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1220e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1958e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.5206e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.9624e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6604e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.3385e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 3ms/step - loss: 7.6805e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9913e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.8465e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7847e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3409e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5648e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5654e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5770e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.3783e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0968e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.5030e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.9806e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4588e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.3555e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6638e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.5200e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3325e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.4016e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6838e-06

# %%
M.predict(denormalized=False)
# Out:
# array([-2.1026284e-04, -2.3078296e-01, -9.2654333e-02,  1.3797432e-02,
#         6.5978333e-02,  1.2864066e-02, -3.4477927e-02], dtype=float32)

# %%
M.evaluate()
# Out:
# {'mape': 6.41, 'mse': 0.0, 'rmse': 136.92}

# %%
M.save('/content/drive/My Drive/Technocolabs/Bitcoin/bitcoin_model_prod_v0.h5')

# %%
M = Model(path='/content/drive/My Drive/Technocolabs/Bitcoin/bitcoin_model_prod_v0.h5',
          data=model_data,
          variable='close',
          predicted_period_size=7)

# %%
M.predict(denormalized=False)
# Out:
# array([-2.1026284e-04, -2.3078296e-01, -9.2654333e-02,  1.3797432e-02,
#         6.5978333e-02,  1.2864066e-02, -3.4477927e-02], dtype=float32)

# %%
i=1
M1 = Model(data=model_data[i * 7:7 * (40 + i) + 7],variable='close',predicted_period_size=7)
M1.build()
M1.train()
results = [] 
for i in range(1, 10 + 1):
    M1.train(epochs=100, verbose=1)
    results.append(M1.evaluate())
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1491e-06
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0970e-06
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9411e-06
# Epoch 4/100
# 1/1 [==============================] - 0s 945us/step - loss: 3.9152e-06
# Epoch 5/100
# 1/1 [==============================] - 0s 942us/step - loss: 4.4106e-06
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6066e-06
# Epoch 7/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9777e-06
# Epoch 8/100
# 1/1 [==============================] - 0s 986us/step - loss: 4.6876e-06
# Epoch 9/100
# 1/1 [==============================] - 0s 963us/step - loss: 4.5835e-06
# Epoch 10/100
# 1/1 [==============================] - 0s 900us/step - loss: 4.0492e-06
# Epoch 11/100
# 1/1 [==============================] - 0s 891us/step - loss: 3.9037e-06
# Epoch 12/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6120e-06
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7660e-06
# Epoch 14/100
# 1/1 [==============================] - 0s 872us/step - loss: 3.8911e-06
# Epoch 15/100
# 1/1 [==============================] - 0s 949us/step - loss: 4.5279e-06
# Epoch 16/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1245e-06
# Epoch 17/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2490e-06
# Epoch 18/100
# 1/1 [==============================] - 0s 936us/step - loss: 6.6850e-06
# Epoch 19/100
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1614e-06
# Epoch 20/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6305e-06
# Epoch 21/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0088e-06
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6420e-06
# Epoch 23/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9460e-06
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1920e-06
# Epoch 25/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7467e-06
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7464e-06
# Epoch 27/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8424e-06
# Epoch 28/100
# 1/1 [==============================] - 0s 947us/step - loss: 4.3418e-06
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1384e-06
# Epoch 30/100
# 1/1 [==============================] - 0s 929us/step - loss: 3.6867e-06
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6541e-06
# Epoch 32/100
# 1/1 [==============================] - 0s 920us/step - loss: 3.5558e-06
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9058e-06
# Epoch 34/100
# 1/1 [==============================] - 0s 964us/step - loss: 4.2421e-06
# Epoch 35/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0801e-06
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.7221e-06
# Epoch 37/100
# 1/1 [==============================] - 0s 3ms/step - loss: 6.7148e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 971us/step - loss: 6.3570e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 987us/step - loss: 5.3138e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0152e-06
# Epoch 41/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6615e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5360e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9865e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2990e-06
# Epoch 45/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8345e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7348e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7239e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1709e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9477e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5373e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5416e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5033e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8991e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2861e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1722e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8394e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.7605e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3211e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 3ms/step - loss: 5.2377e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8969e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.4989e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3579e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7972e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1565e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7579e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7434e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7786e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2241e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9727e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5187e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4704e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3781e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 957us/step - loss: 3.6961e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0197e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8476e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5893e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6424e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.5940e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.7611e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1655e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5012e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1572e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4535e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7999e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4843e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 971us/step - loss: 4.6871e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.9088e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4340e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1758e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6310e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4813e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2688e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4440e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 6ms/step - loss: 3.6244e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 970us/step - loss: 4.2767e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.9752e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1840e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6750e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 3ms/step - loss: 6.6162e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9487e-06
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8717e-06
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1264e-06
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1380e-06
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3294e-06
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9780e-06
# Epoch 6/100
# 1/1 [==============================] - 0s 988us/step - loss: 4.3963e-06
# Epoch 7/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9050e-06
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6738e-06
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5144e-06
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8981e-06
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6398e-06
# Epoch 12/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2707e-06
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2792e-06
# Epoch 14/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2737e-06
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6796e-06
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1704e-06
# Epoch 17/100
# 1/1 [==============================] - 0s 977us/step - loss: 5.2648e-06
# Epoch 18/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2131e-06
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0727e-06
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1786e-06
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8883e-06
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5147e-06
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0692e-06
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9247e-06
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3413e-06
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7900e-06
# Epoch 27/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5219e-06
# Epoch 28/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7057e-06
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8565e-06
# Epoch 30/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3175e-06
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0118e-06
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4719e-06
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3106e-06
# Epoch 34/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1019e-06
# Epoch 35/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2547e-06
# Epoch 36/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4571e-06
# Epoch 37/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1822e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0817e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.5097e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 911us/step - loss: 6.8998e-06
# Epoch 41/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.4578e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6392e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5660e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 7ms/step - loss: 2.8704e-06
# Epoch 45/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8871e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1021e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7689e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2634e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8462e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6791e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5306e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8952e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5952e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 999us/step - loss: 3.1790e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1121e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0393e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3653e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8512e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0216e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2265e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.2720e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3776e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 3ms/step - loss: 5.0191e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4949e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9174e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6761e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9975e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 6ms/step - loss: 3.4305e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2076e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5719e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8893e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4446e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1441e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5406e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2894e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9734e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9908e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0640e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6313e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5000e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.1143e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0518e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0255e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2069e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8619e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8641e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6543e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7020e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2346e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7784e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5388e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6815e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7435e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1528e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8057e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2661e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0567e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8197e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9286e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1766e-06
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0600e-06
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3493e-06
# Epoch 3/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1052e-06
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1565e-06
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1445e-06
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1883e-06
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1611e-06
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5476e-06
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5759e-06
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8107e-06
# Epoch 11/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4811e-06
# Epoch 12/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0519e-06
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7208e-06
# Epoch 14/100
# 1/1 [==============================] - 0s 13ms/step - loss: 4.6536e-06
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5396e-06
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8993e-06
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5445e-06
# Epoch 18/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0521e-06
# Epoch 19/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8707e-06
# Epoch 20/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7007e-06
# Epoch 21/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9061e-06
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3478e-06
# Epoch 23/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5832e-06
# Epoch 24/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.1966e-06
# Epoch 25/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.6670e-06
# Epoch 26/100
# 1/1 [==============================] - 0s 947us/step - loss: 6.7658e-06
# Epoch 27/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2638e-06
# Epoch 28/100
# 1/1 [==============================] - 0s 938us/step - loss: 3.5202e-06
# Epoch 29/100
# 1/1 [==============================] - 0s 975us/step - loss: 2.7668e-06
# Epoch 30/100
# 1/1 [==============================] - 0s 966us/step - loss: 2.3889e-06
# Epoch 31/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5642e-06
# Epoch 32/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9151e-06
# Epoch 33/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6636e-06
# Epoch 34/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2184e-06
# Epoch 35/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7877e-06
# Epoch 36/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5776e-06
# Epoch 37/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3660e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7156e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 906us/step - loss: 3.3532e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8840e-06
# Epoch 41/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7173e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5959e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8768e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 21ms/step - loss: 3.4856e-06
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0254e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.8212e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.8854e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.3627e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7044e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1511e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5483e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2868e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.5304e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9360e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7173e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2652e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7902e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5293e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2819e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6251e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2418e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7682e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5930e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4819e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7763e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4501e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 11ms/step - loss: 5.1496e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1199e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 3ms/step - loss: 8.0733e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2851e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5470e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0224e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4385e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1885e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4217e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8214e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5982e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1820e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7559e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5487e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3227e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6547e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2365e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7244e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5068e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3531e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5685e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1284e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7081e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/step - loss: 6.9160e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4089e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7748e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9179e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.1777e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4523e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0935e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2249e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5411e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2512e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8984e-06
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6249e-06
# Epoch 2/100
# 1/1 [==============================] - 0s 977us/step - loss: 4.6214e-06
# Epoch 3/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.5167e-06
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8580e-06
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4008e-06
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8060e-06
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5031e-06
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2504e-06
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3080e-06
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5824e-06
# Epoch 11/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6190e-06
# Epoch 12/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.6360e-06
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3041e-06
# Epoch 14/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.0180e-06
# Epoch 15/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2364e-06
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9199e-06
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7779e-06
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1069e-06
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0110e-06
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1287e-06
# Epoch 21/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6428e-06
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2628e-06
# Epoch 23/100
# 1/1 [==============================] - 0s 5ms/step - loss: 4.1480e-06
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5546e-06
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8022e-06
# Epoch 26/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2941e-06
# Epoch 27/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8602e-06
# Epoch 28/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1421e-06
# Epoch 29/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7033e-06
# Epoch 30/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2861e-06
# Epoch 31/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1532e-06
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1238e-06
# Epoch 33/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4770e-06
# Epoch 34/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3453e-06
# Epoch 35/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6447e-06
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3561e-06
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9208e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2032e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1779e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6573e-06
# Epoch 41/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0667e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7984e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9421e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2726e-06
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9930e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7401e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6123e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7613e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7170e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9998e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4292e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7287e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3418e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0294e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9782e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0369e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4723e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4963e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2281e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.2331e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.2477e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.9881e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8696e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4042e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8358e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5792e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6939e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0024e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7042e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5401e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5922e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9532e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0164e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2487e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5843e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7737e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3089e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9423e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8355e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8190e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0366e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4150e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4168e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7184e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8917e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.9391e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1425e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9709e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4729e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6210e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3354e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.2690e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4962e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 970us/step - loss: 1.9504e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8622e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9736e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2354e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.4538e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2313e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1694e-06
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3549e-06
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5279e-06
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0839e-06
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7708e-06
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7148e-06
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7898e-06
# Epoch 7/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2281e-06
# Epoch 8/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2973e-06
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.1160e-06
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.1784e-06
# Epoch 11/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.2169e-06
# Epoch 12/100
# 1/1 [==============================] - 0s 8ms/step - loss: 5.9796e-06
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8615e-06
# Epoch 14/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3998e-06
# Epoch 15/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8381e-06
# Epoch 16/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5881e-06
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7117e-06
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0289e-06
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7359e-06
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5571e-06
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5578e-06
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8593e-06
# Epoch 23/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8455e-06
# Epoch 24/100
# 1/1 [==============================] - 0s 959us/step - loss: 4.0390e-06
# Epoch 25/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3397e-06
# Epoch 26/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5808e-06
# Epoch 27/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1866e-06
# Epoch 28/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9836e-06
# Epoch 29/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2147e-06
# Epoch 30/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9812e-06
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3186e-06
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8764e-06
# Epoch 33/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1485e-06
# Epoch 34/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0178e-06
# Epoch 35/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1963e-06
# Epoch 36/100
# 1/1 [==============================] - 0s 972us/step - loss: 1.9801e-06
# Epoch 37/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5295e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6390e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.0317e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0127e-05
# Epoch 41/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.2173e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6887e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6552e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7972e-06
# Epoch 45/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3112e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1687e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1643e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3758e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7617e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5029e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4670e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7388e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4963e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9075e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1168e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.3766e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3325e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.7673e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.2729e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1200e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0429e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2447e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.5946e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.5829e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.5681e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4089e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1789e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2690e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2055e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.4774e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3344e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7837e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8355e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6906e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0062e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1964e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6991e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5266e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4675e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9296e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5696e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4596e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4516e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6313e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9210e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4565e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0880e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0059e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0136e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 5ms/step - loss: 7.3613e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3418e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4557e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2331e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2574e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9362e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3397e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0264e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - loss: 9.6708e-07
# Epoch 99/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0569e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4143e-06
# Epoch 1/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1051e-06
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4713e-06
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1505e-06
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6463e-06
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0885e-06
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0972e-06
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.7296e-06
# Epoch 8/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0858e-06
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5451e-06
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2801e-06
# Epoch 11/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0509e-06
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.0108e-06
# Epoch 13/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0678e-06
# Epoch 14/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4430e-06
# Epoch 15/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2668e-06
# Epoch 16/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9332e-06
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1028e-06
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2452e-06
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4329e-06
# Epoch 20/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1743e-06
# Epoch 21/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4352e-06
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0647e-06
# Epoch 23/100
# 1/1 [==============================] - 0s 4ms/step - loss: 8.9200e-07
# Epoch 24/100
# 1/1 [==============================] - 0s 3ms/step - loss: 8.5862e-07
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3484e-07
# Epoch 26/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1474e-06
# Epoch 27/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5478e-06
# Epoch 28/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3061e-06
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7830e-06
# Epoch 30/100
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8736e-06
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0294e-05
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0941e-05
# Epoch 33/100
# 1/1 [==============================] - 0s 4ms/step - loss: 7.2852e-06
# Epoch 34/100
# 1/1 [==============================] - 0s 5ms/step - loss: 5.5376e-06
# Epoch 35/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1879e-06
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4476e-06
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6704e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2813e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9962e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9357e-06
# Epoch 41/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8927e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9994e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1463e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5510e-06
# Epoch 45/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.0809e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0164e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7989e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5410e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1177e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.5535e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.4758e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.8744e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3460e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2452e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3215e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.7454e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1509e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5885e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7004e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7983e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7106e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9214e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.1158e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1634e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.5371e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.7827e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1230e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7044e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4911e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4746e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7683e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6518e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0386e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 2ms/step - loss: 8.7799e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0782e-05
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1392e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2991e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2829e-06
# ...
# Epoch 9/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.4282e-06
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2855e-06
# Epoch 11/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8035e-06
# Epoch 12/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4859e-06
# Epoch 13/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4117e-06
# Epoch 14/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3263e-06
# Epoch 15/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4506e-06
# Epoch 16/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8037e-06
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5679e-06
# Epoch 18/100
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1127e-06
# Epoch 19/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.9297e-06
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0730e-06
# Epoch 21/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3190e-06
# Epoch 22/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7757e-06
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5249e-06
# Epoch 24/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4724e-06
# Epoch 25/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7108e-06
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3080e-06
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6304e-06
# Epoch 28/100
# 1/1 [==============================] - 0s 3ms/step - loss: 5.4677e-06
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1674e-06
# Epoch 30/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.5025e-06
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.6430e-06
# Epoch 32/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3748e-06
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5556e-06
# Epoch 34/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6755e-06
# Epoch 35/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2404e-06
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9833e-06
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0040e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0302e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0791e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0187e-06
# Epoch 41/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0843e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2347e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7529e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5390e-06
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8205e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4526e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4481e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2489e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4581e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7957e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5787e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3733e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3287e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3924e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8500e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5659e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1109e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7099e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9291e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1724e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 6ms/step - loss: 1.7261e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4956e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5264e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8093e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5913e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9634e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.9996e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.7669e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3765e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9575e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1804e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1900e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5751e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0991e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9813e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9786e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1075e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1091e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1236e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1139e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3541e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7852e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7393e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7262e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.5660e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9770e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2256e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.2501e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8501e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5225e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3846e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2751e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.4670e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9748e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7722e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9711e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4500e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 940us/step - loss: 2.6016e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 865us/step - loss: 1.9930e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6085e-06
# Epoch 1/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.4943e-06
# Epoch 2/100
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5918e-06
# Epoch 3/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0584e-06
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9961e-06
# Epoch 5/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7178e-06
# Epoch 6/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2563e-06
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.7895e-06
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 5.4571e-06
# Epoch 9/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6433e-06
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6428e-06
# Epoch 11/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9746e-06
# Epoch 12/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3177e-06
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0368e-06
# Epoch 14/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9165e-06
# Epoch 15/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0346e-06
# Epoch 16/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1246e-06
# Epoch 17/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2012e-06
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1445e-06
# Epoch 19/100
# 1/1 [==============================] - 0s 4ms/step - loss: 2.2332e-06
# Epoch 20/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4267e-06
# Epoch 21/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0418e-06
# Epoch 22/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.8809e-06
# Epoch 23/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0279e-06
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2001e-06
# Epoch 25/100
# 1/1 [==============================] - 0s 4ms/step - loss: 4.8567e-06
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7734e-06
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2038e-06
# Epoch 28/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7304e-06
# Epoch 29/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5256e-06
# Epoch 30/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3050e-06
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3186e-06
# Epoch 32/100
# 1/1 [==============================] - 0s 5ms/step - loss: 2.5867e-06
# Epoch 33/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2997e-06
# Epoch 34/100
# 1/1 [==============================] - 0s 5ms/step - loss: 3.8776e-06
# Epoch 35/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.7721e-06
# Epoch 36/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9914e-06
# Epoch 37/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2792e-06
# Epoch 38/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7624e-06
# Epoch 39/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5322e-06
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5033e-06
# Epoch 41/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7772e-06
# Epoch 42/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4152e-06
# Epoch 43/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7437e-06
# Epoch 44/100
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3968e-06
# Epoch 45/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.7161e-06
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8946e-06
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.0392e-06
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9828e-06
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3511e-06
# Epoch 50/100
# 1/1 [==============================] - 0s 6ms/step - loss: 2.5954e-06
# Epoch 51/100
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1738e-06
# Epoch 52/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9066e-06
# Epoch 53/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9384e-06
# Epoch 54/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0446e-06
# Epoch 55/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2148e-06
# Epoch 56/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2093e-06
# Epoch 57/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2399e-06
# Epoch 58/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2844e-06
# Epoch 59/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6551e-06
# Epoch 60/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2456e-06
# Epoch 61/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3146e-06
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9672e-06
# Epoch 63/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1711e-06
# Epoch 64/100
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2552e-06
# Epoch 65/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6054e-06
# Epoch 66/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9749e-06
# Epoch 67/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.7103e-06
# Epoch 68/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4117e-06
# Epoch 69/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3049e-06
# Epoch 70/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3771e-06
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9005e-06
# Epoch 72/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5920e-06
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8834e-06
# Epoch 74/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3074e-06
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5643e-06
# Epoch 76/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9383e-06
# Epoch 77/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.6072e-06
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4787e-06
# Epoch 79/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6205e-06
# Epoch 80/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0526e-06
# Epoch 81/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0532e-06
# Epoch 82/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5389e-06
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2450e-06
# Epoch 84/100
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1747e-06
# Epoch 85/100
# 1/1 [==============================] - 0s 4ms/step - loss: 5.4328e-06
# Epoch 86/100
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2447e-06
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6542e-06
# Epoch 88/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8843e-06
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3751e-06
# Epoch 90/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9650e-06
# Epoch 91/100
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8779e-06
# Epoch 92/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9260e-06
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1396e-06
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2347e-06
# Epoch 95/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.2924e-06
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2603e-06
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4647e-06
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8351e-06
# Epoch 99/100
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6888e-06
# Epoch 100/100
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4907e-06

# %%
for i, result in enumerate(results):
    print(f'Week {40+i+1}: {result}')
# Out:
# Week 41: {'mse': 0.0, 'rmse': 119.92, 'mape': 6.42}
# Week 42: {'mse': 0.0, 'rmse': 119.95, 'mape': 6.43}
# Week 43: {'mse': 0.0, 'rmse': 119.29, 'mape': 6.41}
# Week 44: {'mse': 0.0, 'rmse': 119.19, 'mape': 6.41}
# Week 45: {'mse': 0.0, 'rmse': 118.56, 'mape': 6.43}
# Week 46: {'mse': 0.0, 'rmse': 119.48, 'mape': 6.42}
# Week 47: {'mse': 0.0, 'rmse': 118.06, 'mape': 6.45}
# Week 48: {'mse': 0.0, 'rmse': 119.67, 'mape': 6.42}
# Week 49: {'mse': 0.0, 'rmse': 118.53, 'mape': 6.43}
# Week 50: {'mse': 0.0, 'rmse': 119.58, 'mape': 6.42}

# %%
M1.predict(denormalized=True)
# Out:
# array([1233.491  ,  959.16425, 1123.9797 , 1244.4824 , 1316.6769 ,
#        1247.9026 , 1183.0591 ], dtype=float32)

# %%
old_data = model_data[0*7:7*48 + 7]
new_data = model_data[0*7:7*49 + 7]

# %%
M2 = Model(data=old_data,
          variable='close',
          predicted_period_size=7)

# %%
M2.build()
M2.train()

# %%
M2.predict(denormalized=True)
# Out:
# array([1416.6804, 1096.149 , 1292.9758, 1433.6345, 1513.5066, 1437.2677,
#        1369.313 ], dtype=float32)

# %%
M3 = Model(data=new_data,
          variable='close',
          predicted_period_size=7)

# %%
M3.build()
M3.train()

# %%
M3.predict(denormalized=True)
# Out:
# array([1421.251 , 1097.8776, 1291.791 , 1436.1191, 1519.5137, 1439.2966,
#        1367.3314], dtype=float32)

# %%
M3.evaluate()
# Out:
# {'mape': 6.42, 'mse': 0.0, 'rmse': 138.01}
